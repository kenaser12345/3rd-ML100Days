# %% [markdown]
# ## Work
# 1. 請比較使用不同層數以及不同 Dropout rate 對訓練的效果
# 2. 將 optimizer 改成使用 Adam 並加上適當的 dropout rate 檢視結果

# %%
import os
import keras
import itertools
# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = "1"
# Out:
# Using TensorFlow backend.

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from keras.layers import Dropout

def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128], drp_ratio=0.2):
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(input_layer)
            x = Dropout(drp_ratio)(x)
        else:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(x)
            x = Dropout(drp_ratio)(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
LEARNING_RATE = 1e-3
EPOCHS = 50
BATCH_SIZE = 256
MOMENTUM = 0.95
Dropout_EXP = 0.35

# %%
results = {}
model = build_mlp(input_shape=x_train.shape[1:], drp_ratio=Dropout_EXP)
model.summary()
optimizer = keras.optimizers.Adam(lr=LEARNING_RATE)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

model.fit(x_train, y_train, 
          epochs=EPOCHS, 
          batch_size=BATCH_SIZE, 
          validation_data=(x_test, y_test), 
          shuffle=True)

# Collect results
train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]
train_acc = model.history.history["accuracy"]
valid_acc = model.history.history["val_accuracy"]
# Out:
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 512)               0
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 256)               0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 128)               0
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 23s 459us/step - loss: 2.1049 - accuracy: 0.2126 - val_loss: 1.9167 - val_accuracy: 0.3038
# Epoch 2/50
# 50000/50000 [==============================] - 11s 228us/step - loss: 1.9589 - accuracy: 0.2731 - val_loss: 1.8503 - val_accuracy: 0.3464
# Epoch 3/50
# 50000/50000 [==============================] - 11s 212us/step - loss: 1.9100 - accuracy: 0.2979 - val_loss: 1.8450 - val_accuracy: 0.3336
# Epoch 4/50
# 50000/50000 [==============================] - 11s 212us/step - loss: 1.9018 - accuracy: 0.3012 - val_loss: 1.8049 - val_accuracy: 0.3590
# Epoch 5/50
# 50000/50000 [==============================] - 11s 212us/step - loss: 1.8690 - accuracy: 0.3184 - val_loss: 1.8000 - val_accuracy: 0.3639
# Epoch 6/50
# 50000/50000 [==============================] - 11s 212us/step - loss: 1.8606 - accuracy: 0.3183 - val_loss: 1.7948 - val_accuracy: 0.3602
# Epoch 7/50
# 50000/50000 [==============================] - 11s 216us/step - loss: 1.8428 - accuracy: 0.3278 - val_loss: 1.7899 - val_accuracy: 0.3732
# Epoch 8/50
# 50000/50000 [==============================] - 11s 214us/step - loss: 1.8281 - accuracy: 0.3339 - val_loss: 1.8118 - val_accuracy: 0.3702
# Epoch 9/50
# 50000/50000 [==============================] - 11s 211us/step - loss: 1.8217 - accuracy: 0.3384 - val_loss: 1.7418 - val_accuracy: 0.3967
# Epoch 10/50
# 50000/50000 [==============================] - 11s 212us/step - loss: 1.8197 - accuracy: 0.3408 - val_loss: 1.7466 - val_accuracy: 0.3872
# Epoch 11/50
# 50000/50000 [==============================] - 11s 212us/step - loss: 1.8067 - accuracy: 0.3444 - val_loss: 1.7267 - val_accuracy: 0.3975
# Epoch 12/50
# 50000/50000 [==============================] - 11s 212us/step - loss: 1.7980 - accuracy: 0.3463 - val_loss: 1.7474 - val_accuracy: 0.3796
# Epoch 13/50
# 50000/50000 [==============================] - 11s 218us/step - loss: 1.7899 - accuracy: 0.3544 - val_loss: 1.7219 - val_accuracy: 0.4069
# Epoch 14/50
# 50000/50000 [==============================] - 11s 216us/step - loss: 1.7859 - accuracy: 0.3562 - val_loss: 1.7635 - val_accuracy: 0.3848
# Epoch 15/50
# 50000/50000 [==============================] - 11s 215us/step - loss: 1.7845 - accuracy: 0.3557 - val_loss: 1.7699 - val_accuracy: 0.3893
# Epoch 16/50
# 50000/50000 [==============================] - 11s 214us/step - loss: 1.7793 - accuracy: 0.3587 - val_loss: 1.7136 - val_accuracy: 0.4001
# Epoch 17/50
# 50000/50000 [==============================] - 11s 217us/step - loss: 1.7666 - accuracy: 0.3649 - val_loss: 1.7341 - val_accuracy: 0.4057
# Epoch 18/50
# 50000/50000 [==============================] - 11s 215us/step - loss: 1.7664 - accuracy: 0.3622 - val_loss: 1.7447 - val_accuracy: 0.3886
# Epoch 19/50
# 50000/50000 [==============================] - 11s 213us/step - loss: 1.7647 - accuracy: 0.3662 - val_loss: 1.7226 - val_accuracy: 0.4030
# Epoch 20/50
# 50000/50000 [==============================] - 11s 214us/step - loss: 1.7487 - accuracy: 0.3736 - val_loss: 1.7218 - val_accuracy: 0.3951
# Epoch 21/50
# 50000/50000 [==============================] - 11s 212us/step - loss: 1.7540 - accuracy: 0.3697 - val_loss: 1.7180 - val_accuracy: 0.4067
# Epoch 22/50
# 50000/50000 [==============================] - 11s 217us/step - loss: 1.7469 - accuracy: 0.3712 - val_loss: 1.7260 - val_accuracy: 0.4097
# Epoch 23/50
# 50000/50000 [==============================] - 11s 212us/step - loss: 1.7454 - accuracy: 0.3693 - val_loss: 1.6952 - val_accuracy: 0.4149
# Epoch 24/50
# 50000/50000 [==============================] - 11s 227us/step - loss: 1.7363 - accuracy: 0.3759 - val_loss: 1.7139 - val_accuracy: 0.3950
# Epoch 25/50
# 50000/50000 [==============================] - 18s 369us/step - loss: 1.7405 - accuracy: 0.3741 - val_loss: 1.6739 - val_accuracy: 0.4187
# Epoch 26/50
# 50000/50000 [==============================] - 15s 293us/step - loss: 1.7319 - accuracy: 0.3744 - val_loss: 1.7010 - val_accuracy: 0.4094
# Epoch 27/50
# 50000/50000 [==============================] - 14s 274us/step - loss: 1.7314 - accuracy: 0.3797 - val_loss: 1.6761 - val_accuracy: 0.4188
# Epoch 28/50
# 50000/50000 [==============================] - 19s 382us/step - loss: 1.7283 - accuracy: 0.3793 - val_loss: 1.7249 - val_accuracy: 0.3942
# Epoch 29/50
# 50000/50000 [==============================] - 27s 544us/step - loss: 1.7212 - accuracy: 0.3813 - val_loss: 1.6751 - val_accuracy: 0.4209
# Epoch 30/50
# 50000/50000 [==============================] - 23s 453us/step - loss: 1.7277 - accuracy: 0.3803 - val_loss: 1.6802 - val_accuracy: 0.4172
# Epoch 31/50
# 50000/50000 [==============================] - 13s 263us/step - loss: 1.7191 - accuracy: 0.3826 - val_loss: 1.6602 - val_accuracy: 0.4200
# Epoch 32/50
# 50000/50000 [==============================] - 12s 237us/step - loss: 1.7147 - accuracy: 0.3835 - val_loss: 1.6553 - val_accuracy: 0.4283
# Epoch 33/50
# 50000/50000 [==============================] - 10s 209us/step - loss: 1.7185 - accuracy: 0.3849 - val_loss: 1.6655 - val_accuracy: 0.4280
# Epoch 34/50
# 50000/50000 [==============================] - 12s 242us/step - loss: 1.7090 - accuracy: 0.3846 - val_loss: 1.6768 - val_accuracy: 0.4231
# Epoch 35/50
# 50000/50000 [==============================] - 11s 215us/step - loss: 1.7006 - accuracy: 0.3899 - val_loss: 1.6653 - val_accuracy: 0.4152
# Epoch 36/50
# 50000/50000 [==============================] - 11s 217us/step - loss: 1.7126 - accuracy: 0.3869 - val_loss: 1.6687 - val_accuracy: 0.4234
# Epoch 37/50
# 50000/50000 [==============================] - 11s 225us/step - loss: 1.7076 - accuracy: 0.3879 - val_loss: 1.6677 - val_accuracy: 0.4243
# Epoch 38/50
# 50000/50000 [==============================] - 15s 304us/step - loss: 1.6977 - accuracy: 0.3920 - val_loss: 1.6454 - val_accuracy: 0.4284
# Epoch 39/50
# 50000/50000 [==============================] - 12s 241us/step - loss: 1.6960 - accuracy: 0.3890 - val_loss: 1.6690 - val_accuracy: 0.4212
# Epoch 40/50
# 50000/50000 [==============================] - 11s 212us/step - loss: 1.6960 - accuracy: 0.3932 - val_loss: 1.6604 - val_accuracy: 0.4303
# Epoch 41/50
# 50000/50000 [==============================] - 12s 240us/step - loss: 1.6900 - accuracy: 0.3945 - val_loss: 1.6350 - val_accuracy: 0.4279
# Epoch 42/50
# 50000/50000 [==============================] - 10s 207us/step - loss: 1.6946 - accuracy: 0.3931 - val_loss: 1.6666 - val_accuracy: 0.4179s - loss: 1.7
# Epoch 43/50
# 50000/50000 [==============================] - 12s 236us/step - loss: 1.6921 - accuracy: 0.3930 - val_loss: 1.6987 - val_accuracy: 0.4160
# Epoch 44/50
# 50000/50000 [==============================] - 13s 268us/step - loss: 1.6911 - accuracy: 0.3946 - val_loss: 1.6609 - val_accuracy: 0.4249
# Epoch 45/50
# 50000/50000 [==============================] - 20s 392us/step - loss: 1.6888 - accuracy: 0.3947 - val_loss: 1.6402 - val_accuracy: 0.4314
# Epoch 46/50
# 50000/50000 [==============================] - 20s 399us/step - loss: 1.6903 - accuracy: 0.3945 - val_loss: 1.6251 - val_accuracy: 0.4401
# Epoch 47/50
# 50000/50000 [==============================] - 16s 311us/step - loss: 1.6848 - accuracy: 0.3940 - val_loss: 1.6214 - val_accuracy: 0.4386
# Epoch 48/50
# 50000/50000 [==============================] - 12s 250us/step - loss: 1.6795 - accuracy: 0.3970 - val_loss: 1.6493 - val_accuracy: 0.4315
# Epoch 49/50
# 50000/50000 [==============================] - 12s 241us/step - loss: 1.6780 - accuracy: 0.3980 - val_loss: 1.6340 - val_accuracy: 0.4394
# Epoch 50/50
# 50000/50000 [==============================] - 13s 261us/step - loss: 1.6829 - accuracy: 0.3991 - val_loss: 1.6455 - val_accuracy: 0.4237

# %%
#dropour rate 0.25
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
plt.legend()
plt.title("Loss")
plt.show()

plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
plt.legend()
plt.title("Accuracy")
plt.show()

# %%
#dropout rate 0.5
import matplotlib.pyplot as plt

# %matplotlib inline

plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
plt.legend()
plt.title("Loss")
plt.show()

plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
plt.legend()
plt.title("Accuracy")
plt.show()

# %%
#dropout rate 0.35
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
plt.legend()
plt.title("Loss")
plt.show()

plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
plt.legend()
plt.title("Accuracy")
plt.show()
