# %% [markdown]
# ## Work
# 1. 試比較 save_best_only 與否的差異
# 2. 請僅存入將 save_weights_only 設定為 True, 並嘗試 reset ipynb 並將模型與權重重新建回並預測 x_test

# %%
import os
import keras

# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = "1"
# Out:
# Using TensorFlow backend.

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from keras.layers import BatchNormalization
def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128]):
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(input_layer)
            x = BatchNormalization()(x)
        else:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(x)
            x = BatchNormalization()(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
LEARNING_RATE = 1e-3
EPOCHS = 50
BATCH_SIZE = 1024
MOMENTUM = 0.95

# %%
# 載入 Callbacks
from keras.callbacks import ModelCheckpoint

model_ckpt = ModelCheckpoint(filepath="./tmp.h5", 
                             monitor="val_loss", 
                             save_best_only=True,
                             save_weights_only=True)

results = {}
model = build_mlp(input_shape=x_train.shape[1:])
model.summary()
optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

model.fit(x_train, y_train, 
          epochs=EPOCHS, 
          batch_size=BATCH_SIZE, 
          validation_data=(x_test, y_test), 
          shuffle=True,
          callbacks=[model_ckpt]
         )

# Collect results
train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]
train_acc = model.history.history["accuracy"]
valid_acc = model.history.history["val_accuracy"]

# Load back
model = keras.models.load_weights("./tmp.h5")
loss_loadback, acc_loadback = model.evaluate(x_test, y_test)
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 93s 2ms/step - loss: 2.2047 - accuracy: 0.2704 - val_loss: 2.1114 - val_accuracy: 0.2283
# Epoch 2/50
# 50000/50000 [==============================] - 52s 1ms/step - loss: 1.7345 - accuracy: 0.3933 - val_loss: 1.9528 - val_accuracy: 0.3017
# Epoch 3/50
# 50000/50000 [==============================] - 7s 141us/step - loss: 1.6101 - accuracy: 0.4359 - val_loss: 1.8157 - val_accuracy: 0.3727
# Epoch 4/50
# 50000/50000 [==============================] - 7s 138us/step - loss: 1.5384 - accuracy: 0.4627 - val_loss: 1.7100 - val_accuracy: 0.4093
# Epoch 5/50
# 50000/50000 [==============================] - 7s 149us/step - loss: 1.4855 - accuracy: 0.4820 - val_loss: 1.6337 - val_accuracy: 0.4277
# Epoch 6/50
# 50000/50000 [==============================] - 7s 139us/step - loss: 1.4407 - accuracy: 0.4967 - val_loss: 1.5787 - val_accuracy: 0.4455
# Epoch 7/50
# 50000/50000 [==============================] - 7s 149us/step - loss: 1.4010 - accuracy: 0.5107 - val_loss: 1.5487 - val_accuracy: 0.4512
# Epoch 8/50
# 50000/50000 [==============================] - 9s 185us/step - loss: 1.3664 - accuracy: 0.5234 - val_loss: 1.5186 - val_accuracy: 0.4619
# Epoch 9/50
# 50000/50000 [==============================] - 52s 1ms/step - loss: 1.3341 - accuracy: 0.5367 - val_loss: 1.5074 - val_accuracy: 0.4628
# Epoch 10/50
# 50000/50000 [==============================] - 6s 126us/step - loss: 1.3051 - accuracy: 0.5464 - val_loss: 1.4876 - val_accuracy: 0.4713
# Epoch 11/50
# 50000/50000 [==============================] - 6s 130us/step - loss: 1.2764 - accuracy: 0.5572 - val_loss: 1.5027 - val_accuracy: 0.4696
# Epoch 12/50
# 50000/50000 [==============================] - 7s 133us/step - loss: 1.2503 - accuracy: 0.5676 - val_loss: 1.4763 - val_accuracy: 0.4775
# Epoch 13/50
# 50000/50000 [==============================] - 7s 132us/step - loss: 1.2248 - accuracy: 0.5777 - val_loss: 1.4655 - val_accuracy: 0.4775
# Epoch 14/50
# 50000/50000 [==============================] - 7s 143us/step - loss: 1.1988 - accuracy: 0.5893 - val_loss: 1.4717 - val_accuracy: 0.4771
# Epoch 15/50
# 50000/50000 [==============================] - 8s 151us/step - loss: 1.1757 - accuracy: 0.5939 - val_loss: 1.4587 - val_accuracy: 0.4810
# Epoch 16/50
# 50000/50000 [==============================] - 7s 140us/step - loss: 1.1510 - accuracy: 0.6058 - val_loss: 1.4534 - val_accuracy: 0.4831
# Epoch 17/50
# 50000/50000 [==============================] - 7s 143us/step - loss: 1.1279 - accuracy: 0.6123 - val_loss: 1.4702 - val_accuracy: 0.4809
# Epoch 18/50
# 50000/50000 [==============================] - 6s 127us/step - loss: 1.1060 - accuracy: 0.6216 - val_loss: 1.4555 - val_accuracy: 0.4895
# Epoch 19/50
# 50000/50000 [==============================] - 6s 127us/step - loss: 1.0845 - accuracy: 0.6306 - val_loss: 1.4554 - val_accuracy: 0.4897
# Epoch 20/50
# 50000/50000 [==============================] - 8s 163us/step - loss: 1.0628 - accuracy: 0.6387 - val_loss: 1.4569 - val_accuracy: 0.4821
# Epoch 21/50
# 50000/50000 [==============================] - 7s 144us/step - loss: 1.0410 - accuracy: 0.6481 - val_loss: 1.4642 - val_accuracy: 0.4854
# Epoch 22/50
# 50000/50000 [==============================] - 7s 137us/step - loss: 1.0194 - accuracy: 0.6565 - val_loss: 1.4616 - val_accuracy: 0.4928
# Epoch 23/50
# 50000/50000 [==============================] - 7s 142us/step - loss: 0.9998 - accuracy: 0.6635 - val_loss: 1.4611 - val_accuracy: 0.4923
# Epoch 24/50
# 50000/50000 [==============================] - 7s 142us/step - loss: 0.9771 - accuracy: 0.6723 - val_loss: 1.4674 - val_accuracy: 0.4896
# Epoch 25/50
# 50000/50000 [==============================] - 7s 135us/step - loss: 0.9565 - accuracy: 0.6789 - val_loss: 1.4556 - val_accuracy: 0.4953
# Epoch 26/50
# 50000/50000 [==============================] - 7s 139us/step - loss: 0.9382 - accuracy: 0.6867 - val_loss: 1.4627 - val_accuracy: 0.4930
# Epoch 27/50
# 50000/50000 [==============================] - 7s 144us/step - loss: 0.9157 - accuracy: 0.6944 - val_loss: 1.4709 - val_accuracy: 0.4926
# Epoch 28/50
# 50000/50000 [==============================] - 7s 135us/step - loss: 0.8984 - accuracy: 0.7023 - val_loss: 1.4702 - val_accuracy: 0.4887
# Epoch 29/50
# 50000/50000 [==============================] - 7s 133us/step - loss: 0.8779 - accuracy: 0.7119 - val_loss: 1.4870 - val_accuracy: 0.4856
# Epoch 30/50
# 50000/50000 [==============================] - 7s 137us/step - loss: 0.8586 - accuracy: 0.7162 - val_loss: 1.4940 - val_accuracy: 0.4902
# Epoch 31/50
# 50000/50000 [==============================] - 7s 145us/step - loss: 0.8381 - accuracy: 0.7239 - val_loss: 1.4943 - val_accuracy: 0.4896
# Epoch 32/50
# 50000/50000 [==============================] - 8s 151us/step - loss: 0.8165 - accuracy: 0.7335 - val_loss: 1.4924 - val_accuracy: 0.4923
# Epoch 33/50
# 50000/50000 [==============================] - 7s 143us/step - loss: 0.7983 - accuracy: 0.7413 - val_loss: 1.5136 - val_accuracy: 0.4907
# Epoch 34/50
# 50000/50000 [==============================] - 7s 138us/step - loss: 0.7799 - accuracy: 0.7493 - val_loss: 1.5115 - val_accuracy: 0.4895
# Epoch 35/50
# 50000/50000 [==============================] - 7s 143us/step - loss: 0.7603 - accuracy: 0.7580 - val_loss: 1.5327 - val_accuracy: 0.4883
# Epoch 36/50
# 50000/50000 [==============================] - 7s 135us/step - loss: 0.7424 - accuracy: 0.7627 - val_loss: 1.5352 - val_accuracy: 0.4919
# Epoch 37/50
# 50000/50000 [==============================] - 7s 136us/step - loss: 0.7224 - accuracy: 0.7722 - val_loss: 1.5206 - val_accuracy: 0.4946
# Epoch 38/50
# 50000/50000 [==============================] - 7s 144us/step - loss: 0.7042 - accuracy: 0.7778 - val_loss: 1.5260 - val_accuracy: 0.4929
# Epoch 39/50
# 50000/50000 [==============================] - 7s 142us/step - loss: 0.6841 - accuracy: 0.7862 - val_loss: 1.5592 - val_accuracy: 0.4931
# Epoch 40/50
# 50000/50000 [==============================] - 7s 139us/step - loss: 0.6659 - accuracy: 0.7950 - val_loss: 1.5840 - val_accuracy: 0.4879
# Epoch 41/50
# 50000/50000 [==============================] - 8s 152us/step - loss: 0.6476 - accuracy: 0.8009 - val_loss: 1.5644 - val_accuracy: 0.4961
# Epoch 42/50
# 50000/50000 [==============================] - 7s 134us/step - loss: 0.6295 - accuracy: 0.8087 - val_loss: 1.5654 - val_accuracy: 0.4937
# Epoch 43/50
# 50000/50000 [==============================] - 7s 131us/step - loss: 0.6132 - accuracy: 0.8143 - val_loss: 1.5805 - val_accuracy: 0.4910
# Epoch 44/50
# 50000/50000 [==============================] - 7s 134us/step - loss: 0.5958 - accuracy: 0.8206 - val_loss: 1.6004 - val_accuracy: 0.4946
# Epoch 45/50
# 50000/50000 [==============================] - 6s 128us/step - loss: 0.5765 - accuracy: 0.8300 - val_loss: 1.6188 - val_accuracy: 0.4885
# Epoch 46/50
# 50000/50000 [==============================] - 6s 127us/step - loss: 0.5594 - accuracy: 0.8367 - val_loss: 1.6358 - val_accuracy: 0.4893
# Epoch 47/50
# 50000/50000 [==============================] - 6s 127us/step - loss: 0.5425 - accuracy: 0.8423 - val_loss: 1.6654 - val_accuracy: 0.4857
# Epoch 48/50
# 50000/50000 [==============================] - 6s 124us/step - loss: 0.5273 - accuracy: 0.8498 - val_loss: 1.6546 - val_accuracy: 0.4863
# Epoch 49/50
# 50000/50000 [==============================] - 6s 125us/step - loss: 0.5087 - accuracy: 0.8563 - val_loss: 1.6749 - val_accuracy: 0.4892
# Epoch 50/50
# 50000/50000 [==============================] - 6s 122us/step - loss: 0.4919 - accuracy: 0.8631 - val_loss: 1.6703 - val_accuracy: 0.4927
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-aac19093c995> in <module>
#      28
#      29 # Load back
# ---> 30 model = keras.models.load_weights("./tmp.h5")
#      31 loss_loadback, acc_loadback = model.evaluate(x_test, y_test)
#
# AttributeError: module 'keras.models' has no attribute 'load_weights'

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
plt.hlines(y=loss_loadback, xmin=0, xmax=len(train_loss), colors='r', linestyles='--')
plt.legend()
plt.title("Loss")
plt.show()

plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
plt.hlines(y=acc_loadback, xmin=0, xmax=len(train_loss), colors='r', linestyles='--')
plt.legend()
plt.title("Accuracy")
plt.show()
